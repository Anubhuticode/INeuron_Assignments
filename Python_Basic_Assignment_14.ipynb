# %% [markdown]
# # Python_Basic_Assignment_14

# %%
1. What does RGBA stand for?
Ans:Red-Green-Blue-Alpha. The alpha value represents the level of transparency/opacity of the color.

# %%
2. From the Pillow module, how do you get the RGBA value of any images?
Ans:

# %%
from PIL import ImageColor
ImageColor.getcolor('CornflowerBlue','RGBA')
# Out:
# (100, 149, 237, 255)

# %%
3. What is a box tuple, and how does it work?
Ans:Box tuple argument is used to define and image cordinates. It takes 4 arfuments:
        left : The x-coordinate of the leftmost edge of the box.
        top :The y-coordinate of the top edge of the box.
        right:The x-coordinate of one pixel to the right of the rightmost edge of the box.
        bottom: The y-coordinate of one pixel lower than the bottom edge of the box.
            eg. box tuple(2,3,6,9)

# %%
4. Use your image and load in notebook then, How can you find out the width and height of an
Image object?
Ans:

# %%
from PIL import Image
img=Image.open('tiger.png')
width=img.width
height=img.height
print('The height of the image',height)
print('The width of the image',width)
Image.open('tiger.png')
# Out:
# The height of the image 327
# The width of the image 555
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=555x327 at 0x16FBDAD70A0>

# %%
5. What method would you call to get Image object for a 100×100 image, excluding the lower-left
quarter of it?
Ans:image.crop()

# %%
6. After making changes to an Image object, how could you save it as an image file?
Ans:image.save()

# %%
tigerIm=Image.open('tiger.png')
croppedIm = tigerIm.crop((235, 235, 250, 256))
croppedIm.save('cropped.png')
Image.open('cropped.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=15x21 at 0x16FBDB386D0>

# %%
7. What module contains Pillow’s shape-drawing code?
Ans:The ImageDraw module contains code to draw on images.

# %%
8. Image objects do not have drawing methods. What kind of object does? How do you get this kind
of object?
Ans:ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle().
    They are returned by passing the Image object to the ImageDraw.Draw() function.
